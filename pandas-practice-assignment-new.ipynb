# %%
import pandas as pd

# %%
from urllib.request import urlretrieve

urlretrieve('https://hub.jovian.ml/wp-content/uploads/2020/09/countries.csv',
            'countries.csv')
# Out:
# ('countries.csv', <http.client.HTTPMessage at 0x1fb7fafa130>)

# %%
countries_df = pd.read_csv('countries.csv')

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %% [markdown]
# Print a specific row of the `countries_df` dataframe.

# %%
countries_df[countries_df.location == 'China']
# Out:
#    location continent    population  life_expectancy  \
# 41    China      Asia  1.439324e+09            76.91
#
#     hospital_beds_per_thousand  gdp_per_capita           gdp
# 41                        4.34       15308.712  2.203419e+13

# %%
countries_df.loc[41]
# Out:
# location                                      China
# continent                                      Asia
# population                        1439323774.000000
# life_expectancy                           76.910000
# hospital_beds_per_thousand                 4.340000
# gdp_per_capita                         15308.712000
# gdp                           22034193130919.085938
# Name: 41, dtype: object

# %% [markdown]
# **Q: How many countries does the dataframe contain?**
#
# Hint: Use the `.shape` method.

# %%
countries_df.shape
# Out:
# (210, 6)

# %%
countries_df.shape[0]
# Out:
# 210

# %%
num_countries = countries_df.shape[0]

# %%
print('There are {} countries in the dataset.'.format(num_countries))
# Out:
# There are 210 countries in the dataset.

# %% [markdown]
# **Q: Retrieve a list of continents from the dataframe?**
#
# Hint: Use the `.unique` method of a series.

# %%
countries_df['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
countries_df.continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
countries_df['continent'].unique().tolist()
# Out:
# ['Asia', 'Europe', 'Africa', 'North America', 'South America', 'Oceania']

# %%
len(countries_df['continent'].unique().tolist())
# Out:
# 6

# %%
continents = len(countries_df['continent'].unique().tolist())

# %%
print('The overall number of continents is {}.'.format(continents))
# Out:
# The overall number of continents is 6.

# %% [markdown]
# **Q: What is the total population of all the countries listed in this dataset?**

# %%
total_population = countries_df['population'].sum()

# %%
total_population
# Out:
# 7757980095.0

# %%
print('The total population is {}.'.format(int(total_population)))
# Out:
# The total population is 7757980095.

# %% [markdown]
# **Q: (Optional) What is the overall life expectancy across in the world?**
#
# Hint: You'll need to take a weighted average of life expectancy using populations as weights.

# %%
overall_life_expectancy = countries_df['life_expectancy'].sum() / countries_df['population'].sum()

# %%
overall_life_expectancy
# Out:
# 1.961938521833756e-06

# %%
overall_life_expextancy = countries_df['life_expectancy'].sum() / total_population

# %%
overall_life_expectancy
# Out:
# 1.961938521833756e-06

# %% [markdown]
# **Q: Create a dataframe containing 10 countries with the highest population.**
#
# Hint: Chain the `sort_values` and `head` methods.

# %%
most_populous_df = countries_df.sort_values('population', ascending=False).head(10)

# %%
most_populous_df
# Out:
#           location      continent    population  life_expectancy  \
# 41           China           Asia  1.439324e+09            76.91
# 90           India           Asia  1.380004e+09            69.66
# 199  United States  North America  3.310026e+08            78.86
# 91       Indonesia           Asia  2.735236e+08            71.72
# 145       Pakistan           Asia  2.208923e+08            67.27
# 27          Brazil  South America  2.125594e+08            75.88
# 141        Nigeria         Africa  2.061396e+08            54.69
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 157         Russia         Europe  1.459345e+08            72.58
# 125         Mexico  North America  1.289328e+08            75.05
#
#      hospital_beds_per_thousand  gdp_per_capita
# 41                         4.34       15308.712
# 90                         0.53        6426.674
# 199                        2.77       54225.446
# 91                         1.04       11188.744
# ...

# %% [markdown]
# **Q: Add a new column in `countries_df` to record the overall GDP per country (product of population & per capita GDP).**

# %%
countries_df['gdp'] = countries_df['population'] * countries_df['gdp_per_capita']

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 0                          0.50        1803.987  7.022622e+10
# 1                          2.89       11803.431  3.396791e+10
# 2                          1.90       13913.839  6.101364e+11
# ...

# %% [markdown]
# **Q: (Optional) Create a dataframe containing 10 countries with the lowest GDP per capita, among the countries with population greater than 100 million.**

# %%
countries_pop_greater_hundred_mil_df = countries_df[countries_df.population>100000000]

# %%
countries_pop_greater_hundred_mil_df
# Out:
#           location      continent    population  life_expectancy  \
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 27          Brazil  South America  2.125594e+08            75.88
# 41           China           Asia  1.439324e+09            76.91
# 58           Egypt         Africa  1.023344e+08            71.99
# 63        Ethiopia         Africa  1.149636e+08            66.60
# 90           India           Asia  1.380004e+09            69.66
# 91       Indonesia           Asia  2.735236e+08            71.72
# 99           Japan           Asia  1.264765e+08            84.63
# 125         Mexico  North America  1.289328e+08            75.05
# 141        Nigeria         Africa  2.061396e+08            54.69
# 145       Pakistan           Asia  2.208923e+08            67.27
# 151    Philippines           Asia  1.095811e+08            71.23
# 157         Russia         Europe  1.459345e+08            72.58
# ...

# %%
countries_lowest_gdp_per_capita_df = countries_pop_greater_hundred_mil_df.sort_values('gdp_per_capita', ascending=True).head(10)

# %%
countries_lowest_gdp_per_capita_df
# Out:
#         location      continent    population  life_expectancy  \
# 63      Ethiopia         Africa  1.149636e+08            66.60
# 15    Bangladesh           Asia  1.646894e+08            72.59
# 145     Pakistan           Asia  2.208923e+08            67.27
# 141      Nigeria         Africa  2.061396e+08            54.69
# 90         India           Asia  1.380004e+09            69.66
# 151  Philippines           Asia  1.095811e+08            71.23
# 58         Egypt         Africa  1.023344e+08            71.99
# 91     Indonesia           Asia  2.735236e+08            71.72
# 27        Brazil  South America  2.125594e+08            75.88
# 41         China           Asia  1.439324e+09            76.91
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 63                         0.30        1729.927  1.988786e+11
# 15                         0.80        3523.984  5.803628e+11
# 145                        0.60        5034.708  1.112128e+12
# ...

# %% [markdown]
# **Q: Create a data frame that counts the number of countries in each continent?**
#
# Hint: Use `groupby`, select the `location` column and aggregate using `count`.

# %%
country_counts_df = countries_df.groupby('continent')[['location']].count()

# %%
country_counts_df
# Out:
#                location
# continent
# Africa               55
# Asia                 47
# Europe               51
# North America        36
# Oceania               8
# South America        13

# %% [markdown]
# **Q: Create a data frame showing the total population of each continent.**
#
# Hint: Use `groupby`, select the `population` column and aggregate using `sum`.

# %%
continent_populations_df = countries_df.groupby('continent')[['population']].sum()

# %%
continent_populations_df
# Out:
#                  population
# continent
# Africa         1.339424e+09
# Asia           4.607388e+09
# Europe         7.485062e+08
# North America  5.912425e+08
# Oceania        4.095832e+07
# South America  4.304611e+08

# %% [markdown]
# Let's download another CSV file containing overall Covid-19 stats for various countries, and read the data into another Pandas dataframe.

# %%
urlretrieve('https://hub.jovian.ml/wp-content/uploads/2020/09/covid-countries-data.csv',
            'covid-countries-data.csv')
# Out:
# ('covid-countries-data.csv', <http.client.HTTPMessage at 0x1fb7fb89b80>)

# %%
covid_data_df = pd.read_csv('covid-countries-data.csv')

# %%
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %% [markdown]
# **Q: Count the number of countries for which the total_tests data is missing.**
#
# Hint: Use the `.isna` method.

# %%
total_tests_missing = covid_data_df['total_tests'].isna()

# %%
total_tests_missing
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 207     True
# 208     True
# 209     True
# 210     True
# 211    False
# Name: total_tests, Length: 212, dtype: bool

# %%
covid_data_df[total_tests_missing].shape
# Out:
# (122, 4)

# %%
total_tests_missing = covid_data_df[total_tests_missing].shape[0]

# %%
print('The data for total tests is missing for {} countries.'.format(total_tests_missing))
# Out:
# The data for total tests is missing for 122 countries.

# %% [markdown]
# Let's merge the two data frames, and compute some more metrics.
#
# **Q: Merge `countries_df` with `covid_data_df` on the `location` column.**
#
# Hint: Use the `.merge` method on `countries_df`.

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 0                          0.50        1803.987  7.022622e+10
# 1                          2.89       11803.431  3.396791e+10
# 2                          1.90       13913.839  6.101364e+11
# ...

# %%
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %%
combined_df = countries_df.merge(covid_data_df, on='location')

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10      38243.0
# 1                          2.89       11803.431  3.396791e+10       9728.0
# ...

# %% [markdown]
# **Q: Add columns `tests_per_million`, `cases_per_million` and `deaths_per_million` into `combined_df`.**

# %%
combined_df['tests_per_million'] = combined_df.total_tests * 1e6 / combined_df.population

# %%
combined_df['cases_per_million'] = combined_df.total_cases * 1e6 / combined_df.population

# %%
combined_df['deaths_per_million'] = combined_df.total_deaths * 1e6 / combined_df.population

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10      38243.0
# 1                          2.89       11803.431  3.396791e+10       9728.0
# ...

# %% [markdown]
# **Q: Create a dataframe with 10 countries that have the highest number of tests per million people.**

# %%
highest_tests_df = combined_df.sort_values('tests_per_million', ascending=False)[['location', 'tests_per_million']].head(10)

# %%
highest_tests_df
# Out:
#                  location  tests_per_million
# 197  United Arab Emirates      725696.635121
# 14                Bahrain      657527.137965
# 115            Luxembourg      616349.508607
# 122                 Malta      427004.183096
# 53                Denmark      422621.755488
# 96                 Israel      271962.665303
# 89                Iceland      260304.761905
# 157                Russia      254750.159763
# 199         United States      253467.507769
# 10              Australia      245326.517406

# %% [markdown]
# **Q: Create a dataframe with 10 countries that have the highest number of positive cases per million people.**

# %%
highest_cases_df = combined_df.sort_values('cases_per_million', ascending=False)[['location', 'cases_per_million']].head(10)

# %%
highest_cases_df
# Out:
#           location  cases_per_million
# 155          Qatar       41375.743650
# 14         Bahrain       30818.361490
# 147         Panama       21805.112117
# 40           Chile       21695.671982
# 162     San Marino       21657.139490
# 9            Aruba       20708.839893
# 105         Kuwait       20249.789079
# 150           Peru       20121.318048
# 27          Brazil       18808.224105
# 199  United States       18472.377957

# %% [markdown]
# **Q: Create a dataframe with 10 countries that have the highest number of deaths per million people?**

# %%
highest_deaths_df = combined_df.sort_values('deaths_per_million', ascending=False)[['location', 'deaths_per_million']].head(10)

# %%
highest_deaths_df
# Out:
#            location  deaths_per_million
# 162      San Marino         1237.550828
# 150            Peru          887.393445
# 18          Belgium          854.040375
# 3           Andorra          685.950948
# 177           Spain          624.406705
# 198  United Kingdom          611.525168
# 40            Chile          593.423100
# 97            Italy          587.097697
# 27           Brazil          582.331314
# 182          Sweden          576.279276

# %% [markdown]
# **(Optional) Q: Count number of countries that feature in both the lists of "highest number of tests per million" and "highest number of cases per million".**

# %%
count1_df = highest_tests_df.merge(highest_cases_df, on='location')

# %%
count1_df
# Out:
#         location  tests_per_million  cases_per_million
# 0        Bahrain      657527.137965       30818.361490
# 1  United States      253467.507769       18472.377957

# %%
count1_df.shape
# Out:
# (2, 3)

# %%
print('The number of countries that feature in both lists is {}.'.format(count1_df.shape[0]))
# Out:
# The number of countries that feature in both lists is 2.

# %% [markdown]
# **(Optional) Q: Count number of countries that feature in both the lists "20 countries with lowest GDP per capita" and "20 countries with the lowest number of hospital beds per thousand population". Only consider countries with a population higher than 10 million while creating the list.**

# %%
valid_countries = countries_df.population > 10000000

# %%
valid_countries
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 205     True
# 206    False
# 207     True
# 208     True
# 209     True
# Name: population, Length: 210, dtype: bool

# %%
valid_countries.shape
# Out:
# (210,)

# %%
valid_countries_df = countries_df[valid_countries]

# %%
valid_countries_df
# Out:
#         location      continent  population  life_expectancy  \
# 0    Afghanistan           Asia  38928341.0            64.83
# 2        Algeria         Africa  43851043.0            76.88
# 4         Angola         Africa  32866268.0            61.15
# 7      Argentina  South America  45195777.0            76.67
# 10     Australia        Oceania  25499881.0            83.44
# ..           ...            ...         ...              ...
# 204    Venezuela  South America  28435943.0            72.06
# 205      Vietnam           Asia  97338583.0            75.40
# 207        Yemen           Asia  29825968.0            66.12
# 208       Zambia         Africa  18383956.0            63.89
# 209     Zimbabwe         Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 0                          0.50        1803.987  7.022622e+10
# 2                          1.90       13913.839  6.101364e+11
# ...

# %%
valid_countries_df.shape
# Out:
# (90, 7)

# %%
lowest_gdp_per_capita_df = valid_countries_df.sort_values('gdp_per_capita', ascending=True).head(20)

# %%
lowest_gdp_per_capita_df
# Out:
#                          location      continent   population  \
# 32                        Burundi         Africa   11890781.0
# 52   Democratic Republic of Congo         Africa   89561404.0
# 140                         Niger         Africa   24206636.0
# 118                        Malawi         Africa   19129955.0
# 132                    Mozambique         Africa   31255435.0
# 117                    Madagascar         Africa   27691019.0
# 207                         Yemen           Asia   29825968.0
# 176                   South Sudan         Africa   11193729.0
# 85                          Haiti  North America   11402533.0
# 195                        Uganda         Africa   45741000.0
# 31                   Burkina Faso         Africa   20903278.0
# 63                       Ethiopia         Africa  114963583.0
# 39                           Chad         Africa   16425859.0
# 0                     Afghanistan           Asia   38928341.0
# ...

# %%
lowest_number_of_hospital_beds_df = valid_countries_df.sort_values('hospital_beds_per_thousand', ascending=True).head(20)

# %%
lowest_number_of_hospital_beds_df
# Out:
#          location      continent    population  life_expectancy  \
# 121          Mali         Africa  2.025083e+07            59.31
# 117    Madagascar         Africa  2.769102e+07            67.04
# 140         Niger         Africa  2.420664e+07            62.42
# 135         Nepal           Asia  2.913681e+07            70.78
# 82         Guinea         Africa  1.313279e+07            61.60
# 63       Ethiopia         Africa  1.149636e+08            66.60
# 31   Burkina Faso         Africa  2.090328e+07            61.58
# 195        Uganda         Africa  4.574100e+07            63.37
# 0     Afghanistan           Asia  3.892834e+07            64.83
# 20          Benin         Africa  1.212320e+07            61.77
# 90          India           Asia  1.380004e+09            69.66
# 80      Guatemala  North America  1.791557e+07            74.30
# 145      Pakistan           Asia  2.208923e+08            67.27
# 85          Haiti  North America  1.140253e+07            64.00
# ...
